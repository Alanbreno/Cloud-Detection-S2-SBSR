# %%
import mlstac

# %%
ds = mlstac.load("D:\CloudSEN12Plus\main.json")

# %%
ds.metadata
# Out:
#                                           datapoint_id       begin   length  \
# 0     ROI_0002__20190116T142751_20190116T143701_T19GDN           0  3114584
# 1     ROI_0002__20190602T142041_20190602T142839_T19GDN     3114584  2491092
# 2     ROI_0002__20200217T141651_20200217T142551_T19GDN     5605676  2752599
# 3     ROI_0002__20200410T142731_20200410T143742_T19GDN     8358275  2336528
# 4     ROI_0002__20200422T141729_20200422T142243_T19GDN    10694803  2463967
# ...                                                ...         ...      ...
# 1710  ROI_9885__20200723T052651_20200723T053824_T44SMF  1819478737  2728480
# 1711  ROI_9885__20200730T051701_20200730T052738_T44SMF  1822207217  3016410
# 1712  ROI_9885__20190701T051659_20190701T052112_T44SMF  1825223627  3102441
# 1713  ROI_9885__20200409T052639_20200409T053550_T44SMF  1828326068  2733149
# 1714  ROI_9885__20200524T052651_20200524T053821_T44SMF  1831059217  2759289
#
#         roi_id            equi_id equi_zone  \
# ...

# %%
imagens = ds.metadata[(ds.metadata['proj_shape'] == 2000) & (ds.metadata['label_type'] == 'high')]

# %%
sample = mlstac.get_data(dataset=imagens.iloc[0], quiet=True).squeeze()

# %%
sample.shape
# Out:
# (15, 2048, 2048)
